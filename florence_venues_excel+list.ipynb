# %%
import folium as fol
import pandas as pd
from folium.plugins import MarkerCluster

# %%
#Instantiate a map object with the Florence coordinates
m = fol.Map(location=[43.769871, 11.255576], zoom_start=13,tiles='cartodb positron')

# %%
def clean_coordinate_string(s):
     # Remove any extraneous points and return the cleaned string
     s= s[:12]
     return s.replace('.', '',1)

def insert_decimal_point(s, row_number):
    s = clean_coordinate_string(s)
    try:
        return float(s[:2] + '.' + s[2:])
    except Exception as e:
        print(f"Error at row {row_number}: {e}")
        return None

# Read the data
df = pd.read_excel('florence_venues4.xlsx', sheet_name='Foglio1')

# %% [markdown]
# #check type for df latitudes and longitudes
# print(df['latitude'].dtype)

# %% [markdown]
# # Apply the conversion
# df['latitude'] = df.apply(lambda row: insert_decimal_point(str(row['latitude']), row.name), axis=1)
# df['longitude'] = df.apply(lambda row: insert_decimal_point(str(row['longitude']), row.name), axis=1)

# %% [markdown]
# print(df['latitude'][2])

# %% [markdown]
# #drop row 40
# df = df.drop(40)

# %% [markdown]
# #print to test some latitude values
# print(df['latitude'][2])
# print(df['latitude'][3])
# print(df['latitude'][4])
# print(df['latitude'][5])

# %% [markdown]
# df['latitude'] =

# %%
data = """Glue - Alternative concept space: 43.77774040882432, 11.28703587945811
Jazz club: 43.77416126281829, 11.265189936243457
NOF: 43.76928784268565, 11.24600954877033
Sala Vanni: 43.76827798756776, 11.243710992949898
The Speakeasy 23: 43.764459888061275, 11.263453550621588
Ultravox: 43.76444439155579, 11.26361448316035
Visarno Arena: 43.78189788318021, 11.224947950622374
Stadio Artemio Franchi: 43.781712591632584, 11.283897844535796
Ostello Tasso: 43.76588328455833, 11.239405633426564
Il Conventino Caffe letterario, Arte e Artigianato: 43.765099645559786, 11.240645542683687
Le Murate Caffe Letterario: 43.769458871006904, 11.268245048770359
Bar - Ostello Bello Firenze: 43.77817045431577, 11.25137033527851
Barsù - Yellow Square Hostel: 43.78410445104013, 11.241976686978242
Barmezzo - Yellow Square Hostel: 43.78419509711592, 11.2421498690281
Bargiù club - Yellow Square Hostel: 43.78432429358405, 11.24198823244823
Villa Vittoria: 43.77964729678504, 11.249314235028672
Cortile - The Social HUB: 43.78242276740104, 11.253121613141195
Bar e Piscina sul tetto - The Social HUB: 43.78218127931849, 11.25320394743806
Central Club: 43.777579869492556, 11.23584629109893
Otel: 43.76474299089825, 11.311836467816681
TENAX: 43.799013971620894, 11.196001817552093
YAB: 43.77107440370503, 11.252617353005585
Hangar: 43.7722669992825, 11.265030574314808
Il Giardino - La Limonaia: 43.77059092037137, 11.228310050917822
Il Teatro - La Limonaia: 43.7707294060155, 11.228310050917822
Sala Polivalente - La Limonaia: 43.77072077417459, 11.228215612557399
Manifattura Tabacchi: 43.78586097528068, 11.22344873021935
Colle Bereto: 43.771184897771384, 11.252344707360193
Colle Bereto Privé: 43.77122931783797, 11.252464940129473
REX: 43.77257687132047, 11.263159791646041
Via della Mosca 17r: 43.76803166533161, 11.258181955092969
Vineria Sonora: 43.7743972761737, 11.263392261096364
Babylon: 43.773343125212826, 11.270326199036958
Blue Velvet: 43.7682451831864, 11.257080631575253
Caffe' 1926: 43.77317593664171, 11.268634268349414
Club 21: 43.77064916776904, 11.256444302739485
Il Conventino Caffe letterario, Arte e Artigianato - Chiostro: 43.76507695139474, 11.239373134048279"""

# %%
# Initialize an empty dictionary to store the data
locations = {}

# Split the data by lines and iterate over each line
for i, line in enumerate(data.strip().split("\n"), 1):
    # Split each line by ":"
    name, coords = line.split(":")

    try:
        # Extract latitude and longitude
        lat, long = map(float, coords.split(","))
        # Store the data in the dictionary
        locations[name.strip()] = {'lat': lat, 'long': long}
    except ValueError:
        # Print the problematic line
        print(f"Error occurred at line {i}: {line.strip()}")

# Print the dictionary
print(locations)
# Out:
# {'Glue - Alternative concept space': {'lat': 43.77774040882432, 'long': 11.28703587945811}, 'Jazz club': {'lat': 43.77416126281829, 'long': 11.265189936243457}, 'NOF': {'lat': 43.76928784268565, 'long': 11.24600954877033}, 'Sala Vanni': {'lat': 43.76827798756776, 'long': 11.243710992949898}, 'The Speakeasy 23': {'lat': 43.764459888061275, 'long': 11.263453550621588}, 'Ultravox': {'lat': 43.76444439155579, 'long': 11.26361448316035}, 'Visarno Arena': {'lat': 43.78189788318021, 'long': 11.224947950622374}, 'Stadio Artemio Franchi': {'lat': 43.781712591632584, 'long': 11.283897844535796}, 'Ostello Tasso': {'lat': 43.76588328455833, 'long': 11.239405633426564}, 'Il Conventino Caffe letterario, Arte e Artigianato': {'lat': 43.765099645559786, 'long': 11.240645542683687}, 'Le Murate Caffe Letterario': {'lat': 43.769458871006904, 'long': 11.268245048770359}, 'Bar - Ostello Bello Firenze': {'lat': 43.77817045431577, 'long': 11.25137033527851}, 'Barsù - Yellow Square Hostel': {'lat': 43.78410
# ...

# %%
def remove_seconds(s):
    return s[:-3]

df['wday_closing'] = df['wday_closing'].astype(str).apply(remove_seconds)
df['wday_opening'] = df['wday_opening'].astype(str).apply(remove_seconds)
df['wkd_closing'] = df['wkd_closing'].astype(str).apply(remove_seconds)
df['wkd_opening'] = df['wkd_opening'].astype(str).apply(remove_seconds)

# %%
#from locations attach latitude and longitude to the dataframe
#handle errors if names do not coincide, counting the number of errors
#drop it from the dataframe in case not found in locations
errors = 0
for i in range(len(df)):
    try:
        df.at[i, 'latitude'] = locations[df.at[i, 'venue_name']]['lat']
        df.at[i, 'longitude'] = locations[df.at[i, 'venue_name']]['long']
    except KeyError:
        errors += 1
        df.drop(i, inplace=True)
# Out:
# /var/folders/xd/tzsx5trj73g9l2y1d5slm_3r0000gn/T/ipykernel_3821/828459179.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '43.77774040882432' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[i, 'latitude'] = locations[df.at[i, 'venue_name']]['lat']
# /var/folders/xd/tzsx5trj73g9l2y1d5slm_3r0000gn/T/ipykernel_3821/828459179.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '11.28703587945811' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[i, 'longitude'] = locations[df.at[i, 'venue_name']]['long']

# %%
# errors = 0
# for i, row in df.iterrows():
#     try:
#         df.at[i, 'lat'] = locations[row['venue_name']]['lat']
#         df.at[i, 'long'] = locations[row['venue_name']]['long']
#     except KeyError:
#         print(f"Error at row {i}: {row['venue_name']}")
#         errors += 1

# %%
#df['latitude'] = df['venue_name'].map(lambda x: locations[x]['lat'])
#df['longitude'] = df['venue_name'].map(lambda x: locations[x]['long'])

# %%
df[df['venue_name']=='Sala Vanni']
# Out:
#    id  venue_name venue_type main_bus           venue_add_one venue_add_two  \
# 3   4  Sala Vanni     Church       no  Piazza del Carmine, 19       Firenze
#
#    venue_pcode                                          venue_web  \
# 3        50124  https://www.musicusconcentus.com/sala-vanni-nu...
#
#       venue_phone                 venue_email  ... promoters venue_capacity  \
# 3  +39 055 287347  musicusconcentus@gmail.com  ...       NaN            192
#
#   outdoor_space type_outdoor_space  \
# 3             Y                TA
#
#                                       Instagram PRS Type PRS Venue cat  \
# 3  https://www.instagram.com/musicus_concentus/                    NaN
#
#   Year Venue Opened Year Venue Closed Notes
# 3            1992.0               NaN   NaN
#
# [1 rows x 44 columns]

# %%
# locations['OVA Orto Verde Animali']

# %%
df.columns
# Out:
# Index(['id', 'venue_name', 'venue_type', 'main_bus', 'venue_add_one',
#        'venue_add_two', 'venue_pcode', 'venue_web', 'venue_phone',
#        'venue_email', 'venue_fb', 'venue_tw', 'org_own', 'mger', 'mger_email',
#        'mger_phone', 'online_contact_form', 'follow_up', 'venue_city',
#        'venue_country', 'notes', 'std_sign_off', 'res_sign_off', 's_kick_id',
#        'latitude', 'longitude', 'constituency', 'wday_opening', 'wday_closing',
#        'wkd_opening', 'wkd_closing', 'show_opening', 'show_closing',
#        'variations', 'promoters', 'venue_capacity', 'outdoor_space',
#        'type_outdoor_space', 'Instagram', 'PRS Type', 'PRS Venue cat',
#        'Year Venue Opened', 'Year Venue Closed', 'Notes'],
#       dtype='object')

# %%
df['longitude'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 251 entries, 0 to 254
# Series name: longitude
# Non-Null Count  Dtype
# --------------  -----
# 251 non-null    float64
# dtypes: float64(1)
# memory usage: 12.0 KB

# %%
folium_fa_icons = {
    'Social': { 'icon': 'users', 'color': 'blue'},
    'smallvenue': { 'icon': 'building', 'color': 'green'},
    'Bar, pub with music': { 'icon': 'music', 'color': 'purple'},
    'Church': { 'icon': 'church', 'color': 'darkpurple'},
    'Rest': { 'icon': 'bed', 'color': 'cadetblue'},
    'Outgreen': { 'icon': 'tree', 'color': 'darkgreen'},
    'Arena': { 'icon': 'bullhorn', 'color': 'orange'},
    'Stadium': { 'icon': 'flag-checkered', 'color': 'red'},
    'hotelres': { 'icon': 'hotel', 'color': 'beige'},
    'arts': { 'icon': 'paint-brush', 'color': 'pink'},
    'smallclub': { 'icon': 'glass-martini', 'color': 'lightblue'},
    'largeclub': { 'icon': 'music', 'color': 'darkred'},
    'medvenue': { 'icon': 'building', 'color': 'gray'},
    'concert': { 'icon': 'microphone', 'color': 'black'}
}

# %%
folium_fa_icons.update({
    'theatre': { 'icon': 'theater-masks', 'color': 'lightred'},
    'Concert': { 'icon': 'microphone-alt', 'color': 'darkblue'},
    'outurban': { 'icon': 'city', 'color': 'cadetblue'},
    'outgreen': { 'icon': 'leaf', 'color': 'green'},
    'multivenuefest': { 'icon': 'calendar-alt', 'color': 'orange'},
    'largevenue': { 'icon': 'landmark', 'color': 'purple'},
    'arena': { 'icon': 'dove', 'color': 'lightgreen'},
    'student': { 'icon': 'graduation-cap', 'color': 'blue'},
    'other': { 'icon': 'question', 'color': 'grey'},
    'social': { 'icon': 'user-friends', 'color': 'lightblue'},
    'rest': { 'icon': 'utensils', 'color': 'olive'}
})

# %%
default_icon = {'icon': 'circle', 'color': 'gray'} 
print(folium_fa_icons.get('bula',default_icon))
# Out:
# {'icon': 'circle', 'color': 'gray'}

# %%
def check_missing(value, default="N/A"):
    """Return the value or a default string if the value is missing."""
    return value if pd.notna(value) else default
    
def get_icon(venue_type):
    default_icon = {'icon': 'circle', 'color': 'gray'}  # Default vanilla icon
    return folium_fa_icons.get(venue_type, default_icon)


popup_template = """
<h4>{venue_name}</h4>
{address}
{postcode}
{links}
{phone}
{venue_type}
{capacity}
<b>Opening times:</b><br>
{weekdays}
{weekends}
"""
marker_cluster = MarkerCluster().add_to(m)
i = 0
for index, row in df.iterrows():
    i = i +1
    popup_text = popup_template.format(
        venue_name=check_missing(row['venue_name']),
        address=f"<b>Address:</b> {check_missing(row['venue_add_one'])} {check_missing(row['venue_add_two'])}<br>",
        postcode=f"<b>Postcode:</b> {check_missing(row['venue_pcode'])}<br>",
        links=f"<b>Links:</b> <a href='{check_missing(row['venue_web'])}'>Website</a> / <a href='{check_missing(row['venue_fb'])}'>Facebook</a> / <a href='{check_missing(row['Instagram'])}'>Instagram</a><br>",
        phone=f"<b>Phone:</b> {check_missing(row['venue_phone'])}<br>",
        venue_type=f"<b>Venue Type:</b> {check_missing(row['venue_type'])}<br>",
        capacity=f"<b>Capacity:</b> {check_missing(row['venue_capacity'])}<br>",
        weekdays=f"<b>Weekdays Opening:</b> {check_missing(row['wday_opening'])} - {check_missing(row['wday_closing'])}<br>",
        weekends=f"<b>Weekends Opening:</b> {check_missing(row['wkd_opening'])} - {check_missing(row['wkd_closing'])}<br>"
    )
    iframe = fol.IFrame(html=popup_text, width=250, height=250)
    fol.Marker(
        location=[row['latitude'], row['longitude']],
        tooltip=row['venue_name'],
        popup=fol.Popup(iframe, max_width=2650),
        icon=fol.Icon(color=get_icon(row['venue_type'])['color'],prefix='fa', icon=get_icon(row['venue_type'])['icon'])
    ).add_to(marker_cluster)
# Out:
# /var/folders/xd/tzsx5trj73g9l2y1d5slm_3r0000gn/T/ipykernel_3821/3039431735.py:42: UserWarning: color argument of Icon should be one of: {'lightblue', 'red', 'black', 'cadetblue', 'purple', 'beige', 'darkpurple', 'orange', 'green', 'darkblue', 'pink', 'darkred', 'white', 'lightgray', 'blue', 'lightgreen', 'gray', 'lightred', 'darkgreen'}.
#   icon=fol.Icon(color=get_icon(row['venue_type'])['color'],prefix='fa', icon=get_icon(row['venue_type'])['icon'])

# %%
marker_cluster

# %%
i
# Out:
# 251

# %%
m.save('florence_venues4.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#give me longitude of the row with venue name equals red garther
df.loc[df['venue_name'] == 'Red Garter']
# Out:
# Empty DataFrame
# Columns: [id, venue_name, venue_type, main_bus, venue_add_one, venue_add_two, venue_pcode, venue_web, venue_phone, venue_email, venue_fb, venue_tw, org_own, mger, mger_email, mger_phone, online_contact_form, follow_up, venue_city, venue_country, notes, std_sign_off, res_sign_off, s_kick_id, latitude, longitude, constituency, wday_opening, wday_closing, wkd_opening, wkd_closing, show_opening, show_closing, variations, promoters, venue_capacity, outdoor_space, type_outdoor_space, Instagram, PRS Type, PRS Venue cat, Year Venue Opened, Year Venue Closed, Notes]
# Index: []
#
# [0 rows x 44 columns]

# %%
#convert the df to an excel file and save it being sure that latitude and longitude are in text format
